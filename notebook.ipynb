-- %% [markdown]
-- # Сonversion functions

-- %%
CREATE OR REPLACE FUNCTION fn_word_to_bigint(_word TEXT)
RETURNS BIGINT
IMMUTABLE PARALLEL SAFE
AS
$$

SELECT  ASCII(SUBSTRING(_word FROM 1 FOR 1))::BIGINT +
        (ASCII(SUBSTRING(_word FROM 2 FOR 1))::BIGINT << 8) +
        (ASCII(SUBSTRING(_word FROM 3 FOR 1))::BIGINT << 16) +
        (ASCII(SUBSTRING(_word FROM 4 FOR 1))::BIGINT << 24) +
        (ASCII(SUBSTRING(_word FROM 5 FOR 1))::BIGINT << 32)

$$
LANGUAGE 'sql';


CREATE OR REPLACE FUNCTION fn_bigint_to_word(_digits BIGINT)
RETURNS TEXT
IMMUTABLE PARALLEL SAFE
AS
$$

SELECT  CHR((_digits & 255)::INT) ||
        CHR(((_digits >> 8) & 255)::INT) ||
        CHR(((_digits >> 16) & 255)::INT) ||
        CHR(((_digits >> 24) & 255)::INT) ||
        CHR(((_digits >> 32) & 255)::INT)

$$
LANGUAGE 'sql';
-- Out:
-- Commands completed successfully
-- Commands completed successfully
-- Общее время выполнения: 00:00:00.087

-- %% [markdown]
-- # Match functions

-- %%
CREATE OR REPLACE FUNCTION fn_match(_guess BIGINT, _target BIGINT, _position INT)
RETURNS INT
IMMUTABLE PARALLEL SAFE
COST 10000
AS

$$

SELECT  CASE
        WHEN ((_guess >> (8 * _position)) & 255) = ((_target >> (8 * _position)) & 255) THEN 2
        ELSE    (
                (((_guess >> (8 * _position)) & 255) = ((_target >> 0) & 255)
                        AND ((_guess >> 0) & 255) <> ((_target >> 0) & 255)
                        )::INT +
                (((_guess >> (8 * _position)) & 255) = ((_target >> 8) & 255)
                        AND ((_guess >> 8) & 255) <> ((_target >> 8) & 255)
                        )::INT +
                (((_guess >> (8 * _position)) & 255) = ((_target >> 16) & 255)
                        AND ((_guess >> 16) & 255) <> ((_target >> 16) & 255)
                        )::INT +
                (((_guess >> (8 * _position)) & 255) = ((_target >> 24) & 255)
                        AND ((_guess >> 24) & 255) <> ((_target >> 24) & 255)
                        )::INT +
                (((_guess >> (8 * _position)) & 255) = ((_target >> 32) & 255)
                        AND ((_guess >> 32) & 255) <> ((_target >> 32) & 255)
                        )::INT
                >=
                (((_guess >> (8 * _position)) & 255) = ((_guess >> 0) & 255)
                        AND ((_guess >> 0) & 255) <> ((_target >> 0) & 255)
                        )::INT +
                (_position >= 1
                        AND ((_guess >> (8 * _position)) & 255) = ((_guess >> 8) & 255)
                        AND ((_guess >> 8) & 255) <> ((_target >> 8) & 255)
                        )::INT +
                (_position >= 2
                        AND ((_guess >> (8 * _position)) & 255) = ((_guess >> 16) & 255)
                        AND ((_guess >> 16) & 255) <> ((_target >> 16) & 255)
                        )::INT +
                (_position >= 3
                        AND ((_guess >> (8 * _position)) & 255) = ((_guess >> 24) & 255)
                        AND ((_guess >> 24) & 255) <> ((_target >> 24) & 255)
                        )::INT +
                (_position >= 4
                        AND ((_guess >> (8 * _position)) & 255) = ((_guess >> 32) & 255)
                        AND ((_guess >> 32) & 255) <> ((_target >> 32) & 255)
                        )::INT
                )::INT
        END
$$
LANGUAGE 'sql';

CREATE OR REPLACE FUNCTION fn_match(_guess BIGINT, _target BIGINT)
RETURNS INT
IMMUTABLE PARALLEL SAFE
COST 50000
AS

$$

SELECT  fn_match(_guess, _target, 0) +
        fn_match(_guess, _target, 1) * 3 +
        fn_match(_guess, _target, 2) * 9 +
        fn_match(_guess, _target, 3) * 27 +
        fn_match(_guess, _target, 4) * 81

$$
LANGUAGE 'sql';
-- Out:
-- Commands completed successfully
-- Commands completed successfully
-- Общее время выполнения: 00:00:00.087

-- %% [markdown]
-- # Unit tests

-- %%
SELECT  target, guess,
        CASE
        WHEN fn_match_text(fn_match(
                fn_word_to_bigint(guess),
                fn_word_to_bigint(target))
                ) = colors
        THEN
                '✅'
        ELSE    '❌'
        END
FROM    (
        VALUES
        ('AAABB', 'BBAAA', 'YYGYY'),
        ('GHOTI', 'GHOTI', 'GGGGG'),
        ('REBUS', 'RUBUS', 'GBGGG'),
        ('BANAL', 'ANNAL', 'YBGGG'),
        ('BANAL', 'UNION', 'BYBBB'),
        ('BANAL', 'ALLOY', 'YYBBB'),
        ('BANAL', 'BANAL', 'GGGGG'),
        ('ABBEY', 'ABBEY', 'GGGGG'),
        ('ABBEY', 'ABYSS', 'GGYBB'),
        ('ABBEY', 'KEBAB', 'BYGYY'),
        ('ABBEY', 'BABES', 'YYGGB'),
        ('ABBEY', 'OPENS', 'BBYBB'),
        ('DUVET', 'ADDED', 'BYBGB')
        ) AS q (target, guess, colors)
-- Out:
-- (13 row(s) affected)
-- Общее время выполнения: 00:00:00.197
-- <table><tr><th>target</th><th>guess</th><th>case</th></tr><tr><td>AAABB</td><td>BBAAA</td><td>✅</td></tr><tr><td>GHOTI</td><td>GHOTI</td><td>✅</td></tr><tr><td>REBUS</td><td>RUBUS</td><td>✅</td></tr><tr><td>BANAL</td><td>ANNAL</td><td>✅</td></tr><tr><td>BANAL</td><td>UNION</td><td>✅</td></tr><tr><td>BANAL</td><td>ALLOY</td><td>✅</td></tr><tr><td>BANAL</td><td>BANAL</td><td>✅</td></tr><tr><td>ABBEY</td><td>ABBEY</td><td>✅</td></tr><tr><td>ABBEY</td><td>ABYSS</td><td>✅</td></tr><tr><td>ABBEY</td><td>KEBAB</td><td>✅</td></tr><tr><td>ABBEY</td><td>BABES</td><td>✅</td></tr><tr><td>ABBEY</td><td>OPENS</td><td>✅</td></tr><tr><td>DUVET</td><td>ADDED</td><td>✅</td></tr></table>

-- %% [markdown]
-- # Single word
--
-- Let's find the worst case for the word **ALOHA**

-- %%
SELECT  fn_match_text(fn_match(
                fn_word_to_bigint('ALOHA'),
                fn_word_to_bigint(target.word)
                )) AS colors,
        COUNT(*) matches
FROM    wordle AS target
GROUP BY
        colors
ORDER BY
        matches DESC
-- Out:
-- (110 row(s) affected)
-- Общее время выполнения: 00:00:02.075
tr><tr><td>BYGBG</td><td>4</td></tr><tr><td>GGBBG</td><td>4</td></tr><tr><td>YYGBB</td><td>4</td></tr><tr><td>BYBYG</td><td>3</td></tr><tr><td>GYBBG</td><td>3</td></tr><tr><td>GBBGB</td><td>3</td></tr><tr><td>BGGBG</td><td>2</td></tr><tr><td>GGBYB</td><td>2</td></tr><tr><td>GBYYB</td><td>2</td></tr><tr><td>GBYGB</td><td>2</td></tr><tr><td>BYYGB</td><td>2</td></tr><tr><td>YYGYB</td><td>2</td></tr><tr><td>GBBGY</td><td>2</td></tr><tr><td>YYYBG</td><td>2</td></tr><tr><td>BYGYG</td><td>2</td></tr><tr><td>GGYGB</td><td>1</td></tr><tr><td>YGBBY</td><td>1</td></tr><tr><td>YGBGB</td><td>1</td></tr><tr><td>GGYBY</td><td>1</td></tr><tr><td>GGGGG</td><td>1</td></tr><tr><td>GGBYY</td><td>1</td></tr><tr><td>GGBGG</td><td>1</td></tr><tr><td>BBYGG</td><td>1</td></tr><tr><td>GBGBY</td><td>1</td></tr><tr><td>GBGGB</td><td>1</td></tr><tr><td>GBYBY</td><td>1</td></tr><tr><td>GBYBG</td><td>1</td></tr><tr><td>GBGYB</td><td>1</td></tr><tr><td>GBGGG</td><td>1</td></tr><tr><td>BYYYG</td><td>1</td></tr><tr><td>YBGYB</td><td>1</td></tr><tr><td>YBGYG</td><td>1</td></tr><tr><td>GYGYB</td><td>1</td></tr><tr><td>YBYBY</td><td>1</td></tr><tr><td>GYBYB</td><td>1</td></tr><tr><td>BGBGB</td><td>1</td></tr></table>

-- %% [markdown]
-- # All words
--
-- Now, let's find the "best worst case" for every word from the list.
--
-- We are using a CTE to calculate the numeric values of the words.
--
-- The function to calculate the numeric value has high cost, so the optimizer chooses to materialize the CTE.

-- %%
WITH    numeric_wordle AS
        (
        SELECT  fn_word_to_bigint(word) AS word
        FROM    wordle
        )
SELECT  fn_bigint_to_word(word), MAX(matches) AS worst
FROM    (
        SELECT  guess.word,
                fn_match(guess.word, target.word) AS colors,
                COUNT(*) matches
        FROM    numeric_wordle AS guess
        CROSS JOIN
                numeric_wordle AS target
        GROUP BY
                guess.word, colors
        ) q
GROUP BY
        word
ORDER BY
        worst ASC
-- The smaller, the better. The optimal candidate will come out first.
-- Out:
-- (12478 row(s) affected)
-- Отображаются первые 5000 строк.
-- Общее время выполнения: 00:04:31.415
-- <table><tr><th>fn_bigint_to_word</th><th>worst</th></tr><tr><td>SERAI</td><td>659</td></tr><tr><td>SOARE</td><td>724</td></tr><tr><td>PASEO</td><td>747</td></tr><tr><td>AEROS</td><td>749</td></tr><tr><td>STOAE</td><td>781</td></tr><tr><td>REANS</td><td>785</td></tr><tr><td>NEARS</td><td>785</td></tr><tr><td>NARES</td><td>785</td></tr><tr><td>KAIES</td><td>788</td></tr><tr><td>REALS</td><td>791</td></tr><tr><td>SERAL</td><td>791</td></tr><tr><td>RALES</td><td>791</td></tr><tr><td>LEARS</td><td>791</td></tr><tr><td>LARES</td><td>791</td></tr><tr><td>ARLES</td><td>791</td></tr><tr><td>ALO
</td><td>933</td></tr><tr><td>RAPES</td><td>933</td></tr><tr><td>PEARS</td><td>933</td></tr><tr><td>SPAER</td><td>933</td></tr><tr><td>PARES</td><td>933</td></tr><tr><td>APRES</td><td>933</td></tr><tr><td>SPARE</td><td>933</td></tr><tr><td>MARES</td><td>935</td></tr><tr><td>REAMS</td><td>935</td></tr><tr><td>NEATS</td><td>935</td></tr><tr><td>LASER</td><td>937</td></tr><tr><td>SAMEN</td><td>938</td></tr><tr><td>SCALE</td><td>941</td></tr><tr><td>PANES</td><td>942</td></tr><tr><td>NAPES</td><td>942</td></tr><tr><td>AMIES</td><td>942</td></tr><tr><td>SARED</td><td>945</td></tr><tr><td>EARDS</td><td>945</td></tr><tr><td>DARES</td><td>945</td></tr><tr><td>DEARS</td><td>945</td></tr><tr><td>READS</td><td>945</td></tr><tr><td>SAGER</td><td>946</td></tr><tr><td>SEGAR</td><td>94 ...

-- %% [markdown]
-- # Limiting the pool
--
-- To play the actual game of Wordle using the Minimax algorithm, we always start with the word **SERAI**, because in the worst case it does better that all other words.
--
-- To figure out our next guess we need to run the algorithm, limiting the pool of words to those compatible with previous guesses.
--
-- We do it by putting our previous guesses and their color matches into a CTE with inline data, and running the aggregate function `BOOL_AND` in a scalar subquery.

-- %%
WITH    guesses (guess, colors) AS
        (
        VALUES
        ('SERAI', 'BBBBB'),
        ('DONUT', 'BBBBB')
        )
SELECT  word
FROM    wordle
WHERE   (
        SELECT  BOOL_AND(
                fn_match(
                        fn_word_to_bigint(guess),
                        fn_word_to_bigint(word)
                        ) = fn_match_color(colors)
                        )
        FROM    guesses
        )
-- Out:
-- (7 row(s) affected)
-- Общее время выполнения: 00:00:03.614
-- <table><tr><th>word</th></tr><tr><td>FLYBY</td></tr><tr><td>GHYLL</td></tr><tr><td>GLYPH</td></tr><tr><td>GYPPY</td></tr><tr><td>LYMPH</td></tr><tr><td>PYGMY</td></tr><tr><td>XYLYL</td></tr></table>

-- %% [markdown]
-- # Playing Wordle
--
-- Let's play the actual game of Wordle!
--
-- We combine the main algorithm query with the pool-limiting query.

-- %%
WITH    guesses (guess, colors) AS
        (
        VALUES
        ('SERAI', 'YYBBB'),
        ('LOSEN', 'BBYYB'),
        ('THESE', 'YBGGB')
        ),
        numeric_wordle AS
        (
        SELECT  fn_word_to_bigint(word) AS word
        FROM    wordle
        WHERE   (
                SELECT  BOOL_AND(
                        fn_match(
                                fn_word_to_bigint(guess),
                                fn_word_to_bigint(word)
                                ) = fn_match_color(colors)
                                )
                FROM    guesses
                )
        )
SELECT  fn_bigint_to_word(word), MAX(matches) AS worst
FROM    (
        SELECT  guess.word,
                fn_match(guess.word, target.word) AS colors,
                COUNT(*) matches
        FROM    numeric_wordle AS guess
        CROSS JOIN
                numeric_wordle AS target
        GROUP BY
                guess.word, colors
        ) q
GROUP BY
        word
ORDER BY
        worst ASC
LIMIT 1
-- Out:
-- (1 row(s) affected)
-- Общее время выполнения: 00:00:06.348
-- <table><tr><th>fn_bigint_to_word</th><th>worst</th></tr><tr><td>GUEST</td><td>1</td></tr></table>
